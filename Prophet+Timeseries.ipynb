# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from fbprophet import Prophet

data = pd.read_csv('C:/Users/JP/Documents/School/Practicum/Github/Practicum/data/dataset.csv')
df[['ds','y']] = pd.DataFrame(data[['Date','ETHOpen']])
#df['ds'] = pd.to_datetime(df['y'],format='%Y-%m-%d')
#df = df.set_index('Date')

m = Prophet(weekly_seasonality = True)
m.fit(df) 
future = m.make_future_dataframe(periods=7)
forecast=m.predict(future)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast.tail()
# Out:
#             ds       trend  trend_lower  trend_upper  yhat_lower  yhat_upper  \
# 804 2017-10-19  329.491688   329.491688   329.491688  307.861056  361.515819
# 805 2017-10-20  330.727572   330.727572   330.727572  308.531431  359.340835
# 806 2017-10-21  331.963456   331.963456   331.963456  308.437469  360.407652
# 807 2017-10-22  333.199339   333.199339   333.199339  310.427730  362.844567
# 808 2017-10-23  334.435223   334.429298   334.435223  309.055502  361.480961
#
#      seasonal  seasonal_lower  seasonal_upper  seasonalities  \
# 804  4.103935        4.103935        4.103935       4.103935
# 805  3.035324        3.035324        3.035324       3.035324
# 806  2.600788        2.600788        2.600788       2.600788
# 807  2.202220        2.202220        2.202220       2.202220
# 808  1.763764        1.763764        1.763764       1.763764
#
#      seasonalities_lower  seasonalities_upper    weekly  weekly_lower  \
# 804             4.103935             4.103935  0.529461      0.529461
# 805             3.035324             3.035324 -0.185857     -0.185857
# 806             2.600788             2.600788 -0.245022     -0.245022
# 807             2.202220             2.202220 -0.253177     -0.253177
# 808             1.763764             1.763764 -0.292827     -0.292827
#
#      weekly_upper    yearly  yearly_lower  yearly_upper        yhat
# 804      0.529461  3.574473      3.574473      3.574473  333.595623
# 805     -0.185857  3.221182      3.221182      3.221182  333.762896
# 806     -0.245022  2.845810      2.845810      2.845810  334.564244
# 807     -0.253177  2.455396      2.455396      2.455396  335.401559
# 808     -0.292827  2.056591      2.056591      2.056591  336.198987

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
forecast.tail()
# Out:
#             ds       trend  trend_lower  trend_upper  yhat_lower  yhat_upper  \
# 804 2017-10-19  329.491688   329.491688   329.491688  306.854802  360.806073
# 805 2017-10-20  330.727572   330.727572   330.727572  308.284528  358.943093
# 806 2017-10-21  331.963456   331.963456   331.963456  308.849218  358.721826
# 807 2017-10-22  333.199339   333.199339   333.199339  311.127672  362.989348
# 808 2017-10-23  334.435223   334.435200   334.435223  308.634906  363.986650
#
#      seasonal  seasonal_lower  seasonal_upper  seasonalities  \
# 804  4.103935        4.103935        4.103935       4.103935
# 805  3.035324        3.035324        3.035324       3.035324
# 806  2.600788        2.600788        2.600788       2.600788
# 807  2.202220        2.202220        2.202220       2.202220
# 808  1.763764        1.763764        1.763764       1.763764
#
#      seasonalities_lower  seasonalities_upper    weekly  weekly_lower  \
# 804             4.103935             4.103935  0.529461      0.529461
# 805             3.035324             3.035324 -0.185857     -0.185857
# 806             2.600788             2.600788 -0.245022     -0.245022
# 807             2.202220             2.202220 -0.253177     -0.253177
# 808             1.763764             1.763764 -0.292827     -0.292827
#
#      weekly_upper    yearly  yearly_lower  yearly_upper        yhat
# 804      0.529461  3.574473      3.574473      3.574473  333.595623
# 805     -0.185857  3.221182      3.221182      3.221182  333.762896
# 806     -0.245022  2.845810      2.845810      2.845810  334.564244
# 807     -0.253177  2.455396      2.455396      2.455396  335.401559
# 808     -0.292827  2.056591      2.056591      2.056591  336.198987

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from fbprophet import Prophet

data = pd.read_csv('C:/Users/JP/Documents/School/Practicum/Github/Practicum/data/dataset.csv')
#df[['ds','y']] = pd.DataFrame(data[['Date','ETHOpen']])
#df['ds'] = pd.to_datetime(df['ds'],format='%Y-%m-%d')
df = pd.DataFrame(data[['Date','ETHOpen']])
df[['ds','y']] = df 
df = df.set_index('Date')
df = df[df.index>'2017-01-30']
df = df[df.index<'2017-10-05']



m = Prophet(weekly_seasonality = True,yearly_seasonality=True)
m.fit(df) 
future = m.make_future_dataframe(periods=50)

forecast=m.predict(future)
forecast.tail()
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds       trend  trend_lower  trend_upper  yhat_lower  yhat_upper  \
# 292 2017-11-19  370.053302   370.053300   370.053305  358.879406  400.642225
# 293 2017-11-20  371.252833   371.252830   371.252836  359.059329  402.735828
# 294 2017-11-21  372.452364   372.452361   372.452367  362.679909  406.432185
# 295 2017-11-22  373.651895   373.651892   373.651898  364.982042  410.215764
# 296 2017-11-23  374.851426   374.851423   374.851429  367.766173  410.846345
#
#       seasonal  seasonal_lower  seasonal_upper  seasonalities  \
# 292   8.900850        8.900850        8.900850       8.900850
# 293   9.922676        9.922676        9.922676       9.922676
# 294  11.894852       11.894852       11.894852      11.894852
# 295  13.803214       13.803214       13.803214      13.803214
# 296  13.986213       13.986213       13.986213      13.986213
#
#      seasonalities_lower  seasonalities_upper    weekly  weekly_lower  \
# 292             8.900850             8.900850 -1.421507     -1.421507
# 293             9.922676             9.922676 -1.308276     -1.308276
# 294            11.894852            11.894852  0.154743      0.154743
# 295            13.803214            13.803214  1.954134      1.954134
# 296            13.986213            13.986213  2.419691      2.419691
#
#      weekly_upper     yearly  yearly_lower  yearly_upper        yhat
# 292     -1.421507  10.322357     10.322357     10.322357  378.954152
# 293     -1.308276  11.230953     11.230953     11.230953  381.175509
# 294      0.154743  11.740109     11.740109     11.740109  384.347216
# 295      1.954134  11.849080     11.849080     11.849080  387.455109
# 296      2.419691  11.566521     11.566521     11.566521  388.837638

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)
